# %%
from datasets import load_dataset

# %%
query_data_list  = load_dataset('osunlp/TravelPlanner','test')['test']

# %%
d = eval(query_data_list[-1]['reference_information'])

# %%
query_data_list[-10]
# Out:
# {'org': 'Augusta',
#  'dest': 'North Carolina',
#  'days': 7,
#  'date': "['2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17', '2022-03-18', '2022-03-19', '2022-03-20']",
#  'query': "Could you come up with a 7-day travel plan for a party of 3, departing from Augusta and journeying through 3 different cities in North Carolina from March 14th to March 20th, 2022? We are planning to drive, so no flights are needed. We have a budget of $5,400 and we're accompanied by our pets. Food-wise, we're very keen on trying out Indian, Mexican, American, and French cuisines during our trip. We require accommodations that are pet-friendly.",
#  'level': 'hard',
# ...

# %%
for i, q in enumerate(query_data_list):
    if "Seattle to California" in q['query']:
        print(i, q)
# Out:
# 148 {'org': 'Seattle', 'dest': 'California', 'days': 5, 'date': "['2022-03-13', '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17']", 'query': 'Could you generate a travel plan for a 5-day solo trip from Seattle to California, visiting 2 cities between March 13th and March 17th, 2022? The available budget for the journey is $3,800.', 'level': 'easy', 'reference_information': '[{\'Description\': \'Attractions in San Diego\', \'Content\': \'                                      Name  Latitude   Longitude                                                   Address          Phone                                                                                      Website      City\\n                Cabrillo National Monument 32.672256 -117.241609       1800 Cabrillo Memorial Dr, San Diego, CA 92106, USA (619) 523-4285                                                           https://www.nps.gov/cabr/index.htm San Diego\\n                      La Jolla Shores Park 32.858154 -117.256103 
# ...

# %%
ref_info = eval(query_data_list[311]['reference_information'])

# %%
for info in ref_info:
    print(info["Description"])
    for content in info['Content'].split("\n"):
        print(content)
    print("\n\n")
# Out:
# Attractions in San Diego
#                                       Name  Latitude   Longitude                                                   Address          Phone                                                                                      Website      City
#                 Cabrillo National Monument 32.672256 -117.241609       1800 Cabrillo Memorial Dr, San Diego, CA 92106, USA (619) 523-4285                                                           https://www.nps.gov/cabr/index.htm San Diego
#                       La Jolla Shores Park 32.858154 -117.256103              8300 Camino Del Oro, La Jolla, CA 92037, USA (619) 221-8899                                           https://www.sandiego.gov/lifeguards/beaches/shores San Diego
#                           California Tower 32.731609 -117.152167 California Tower, 1350 El Prado, San Diego, CA 92101, USA (619) 239-2001                                            https://museumofus.org/exhibits/california-tower/ San Diego
# ...
